# %%
#Importing the libraries for this project
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

plt.style.use('fivethirtyeight')

# %%
df= web.DataReader('VERU',data_source='yahoo',start='2016-01-01', end='2020-12-23')
#Getting the data for VERU, and showing it
df
# Out:
#              High    Low  Open  Close    Volume  Adj Close
# Date
# 2016-01-04   1.51  1.390  1.41   1.45     77400       1.45
# 2016-01-05   1.48  1.410  1.46   1.43     34900       1.43
# 2016-01-06   1.45  1.330  1.45   1.36    162800       1.36
# 2016-01-07   1.37  1.260  1.34   1.27    115500       1.27
# 2016-01-08   1.35  1.220  1.27   1.24     93900       1.24
# ...           ...    ...   ...    ...       ...        ...
# 2020-12-17  10.02  9.020  9.93   9.30  11618500       9.30
# 2020-12-18   9.23  8.610  8.98   8.81   7793500       8.81
# 2020-12-21   9.13  8.330  8.40   8.86   4772100       8.86
# 2020-12-22   9.47  8.880  9.12   9.29   3749300       9.29
# 2020-12-23   9.30  8.825  9.23   9.13   2880924       9.13
#
# [1254 rows x 6 columns]

# %%
# get the amount of rows, and columns.
df.shape
#The data have 1254 rows, and 6 colums
# Out:
# (1254, 6)

# %%
plt.figure(figsize=(16,8))
plt.title('Close price History')
plt.plot(df['Close'])
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()
